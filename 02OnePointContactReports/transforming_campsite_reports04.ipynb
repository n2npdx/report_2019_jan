# %%
# This code was modified from Hack Oregon's Neighborhood Development project
# https://github.com/hackoregon/neighborhoods-2018/tree/master/notebooks/campsites
# Many thanks to Hasan for collaborating on the data prep through Hack Oregon

# %%
import pyproj
from pyproj import transform

# %%
import pandas as pd
import numpy as np

# %%
# http://www.spatialreference.org/ref/epsg/3646/
or_north_plain = pyproj.Proj(init='EPSG:3646', preserve_units=True)

# %%
def load_csv(fname):
    falsies = ['No', 'NO','no', ]
    trusies = ['YES', 'Yes', 'yes']
    df = pd.read_csv(fname,
                     true_values=trusies,
                     false_values=falsies,
                     parse_dates=[0],
                     low_memory=False,
                     )
    return df

# %%
def transform_coordinates(df, projection):
    # 0 values in X and Y columns are invalid - replace with NaN so we can fix erronous projections
    df.X.replace(0, np.nan, inplace=True)
    df.Y.replace(0, np.nan, inplace=True)
    X = np.array(df.X)
    Y = np.array(df.Y)
    
    lons, lats = projection(X, Y, inverse=True)
    # Projections that don't make sense return 1e+30 rather than erroring.
    # We will replace these with NaNs
    lons[lons == 1e+30] = np.nan
    lats[lats == 1e+30] = np.nan
    df['lon'] = lons
    df['lat'] = lats
    # Get rid of old columns
    df.drop(columns=['X', 'Y'], inplace=True)
    
    return df

# %%
# def transform_coordinates_to_epsg4326(df, projection, outprojection):
#     # 0 values in X and Y columns are invalid - replace with NaN so we can fix erronous projections
#     df.X.replace(0, np.nan, inplace=True)
#     df.Y.replace(0, np.nan, inplace=True)
#     X = np.array(df.X)
#     Y = np.array(df.Y)
    
#     lons, lats = projection(X, Y, inverse=True)
#     # Projections that don't make sense return 1e+30 rather than erroring.
#     # We will replace these with NaNs
#     lons[lons == 1e+30] = np.nan
#     lats[lats == 1e+30] = np.nan
#     df['lon'] = lons
#     df['lat'] = lats
#     # Transform to EPSG 4326
#     (df['lon'], df['lat']) = transform(projection, outprojection, (df['lon'], df['lat']))
#     # Get rid of old columns
#     df.drop(columns=['X', 'Y'], inplace=True)
    
#     return df

# %%
def cleanse_data(df):
    # Get the first number and use that as the new value
    df['num_campers'] = df['How many campers would you estimate are there?'].str.extract(r'(\d+)', expand=False)
    df.drop(columns=['How many campers would you estimate are there?'], inplace=True)
    return df

#This needs to be fixed using the code below. Will do this later.

# %%
CSV_FILES = ['../data/onepointcontactreports/Comstock April 2018-November 25_2018.csv']

# %%
for fname in CSV_FILES:
    df = load_csv(fname)
    completed = transform_coordinates(df, or_north_plain)
    new_name = '_processed.'.join(fname.split('2018.'))
    df.to_csv(new_name, index=False)

# %%
# for fname in CSV_FILES:
#     df = load_csv(fname)
#     completed = transform_coordinates_to_epsg4326(df, or_north_plain, wgs84)
#     new_name = '_processed_epsg4326.'.join(fname.split('2018.'))
#     df.to_csv(new_name, index=False)

# %% [markdown]
# # Playground
#
# ## *TODO*
# - I think extracting column W, in general, is pretty safe, since the question was so direct. With multiple numbers, taking an average of them seems reasonable. We’d need to think about what to do with “+” as many people do that, or say “more than”. My guess is leaving it at the lower bound is fine
# -  the CSV you exported seems to have a funny format for column W.
# - Some of the numbers are printed as dates. If you look at row 2 (first data row, excluding header) and column W - the one asking “How many campers would you estimate are there?” - then you’ll see it listed as Apr-5 rather than a number.
# - If I go through the fields tonight and select the ones to keep, would you be able to extract the numbers from column W and put them in a new column so I can join that field (via report date) to the other file?
# - In terms of keeping columns, I think any qualitative information given about the campsite should stay (i.e. starting with the field “How long has the campsite been there” through the lat/longs
# I think we should keep Date and ID
# Everything inbetween can likely be reduced to a single column with a street address in it, since it was an either/or sort of thing (sometimes there are multiple fields filled in, but if we go most specific to least specific and exclude NAs, it should work fine)
# - "Column W" = “How many campers would you estimate are there?”

# %% [markdown]
# #BREAK
# - At this point, I have deleted the unwanted columns (manually, in Excel) for the old_processed and new_processed .csvs that were generated above.
# - I'm going to change the name of CSV_FILES to the new filenames that I modified outside of this script and proceed with the next few steps.

# %%
CSV_FILES = ['../data/onepointcontactreports/Comstock April 2018-November 25__processed.csv', '../data/onepointcontactreports/campsite_reports_final_HackOR.csv']
print(CSV_FILES)
# Out:
# ['../data/onepointcontactreports/Comstock April 2018-November 25__processed.csv', '../data/onepointcontactreports/campsite_reports_final_HackOR.csv']

# %%
df = load_csv(CSV_FILES[0])
df2 = load_csv(CSV_FILES[1])

# %%
df.head()
print("df2 is {}, df is {}".format(len(df2['Item ID']), len(df['Item ID'])))
# df.to_csv("test_df.csv")
# Out:
# df2 is 32812, df is 21527

# %%
df2.drop('Unnamed: 0', axis=1, inplace=True)
df2.head()
# Out:
#           Date Created    Item ID  \
# 0  2018-03-31 20:58:00  1367525.0
# 1  2018-03-31 20:45:00  1367524.0
# 2  2018-03-31 20:14:00  1367522.0
# 3  2018-03-31 19:38:00  1367515.0
# 4  2018-03-31 19:23:00  1367514.0
#
#   Where is the campsite/concern located? Please provide an address if possible. If no address is available, please provide a complete description of the site's location.  \
# 0                                         Essex Park
# 1                                           Max Stop
# 2  NE Halsey and 68th, between the freeway offram...
# 3                                   Private Property
# 4                                          ODOT I-84
#
#   If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (User Specified)  \
# 0                                       3804 se 79th
# 1                       SE Pershing st & SE 17th ave
# 2                              NE Halsey and 68th Pl
# 3                            NE 74th and NE Roselawn
# 4                                                NaN
#
#   If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (System Verified)  \
# 0                                  7811 SE CENTER ST
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                              1400-1449 NE 68TH AVE
#
#   How long has the site been there? Is the site occupied?  \
# 0                           a while                   yes
# 1                            5 Days                   yes
# 2                               NaN                   yes
# 3                            2 days                   yes
# 4                               NaN                   NaN
#
#   How many campers would you estimate are there? Are children present?  \
# 0                                            NaN                 False
# 1                                              1                 False
# 2                                              8                   NaN
# 3                                              2                 False
# 4                                            NaN                   NaN
#
#   Are dogs present?        ...         \
# 0             False        ...
# 1             False        ...
# 2               NaN        ...
# 3               NaN        ...
# 4               NaN        ...
#
#   Repeated instances of overly aggressive behavior from campers  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Public intoxication and/or conspicuous drug use (If it is an emergency, please call 9-1-1.)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Campsite obstructs public right-of-way  Misuse of public spaces  \
# 0                                   True                     True
# 1                                   True                     True
# 2                                  False                     True
# 3                                  False                     True
# 4                                  False                    False
#
#   Structures or tents present Excessive trash and/or biohazards  \
# 0                       False                              True
# 1                        True                              True
# 2                        True                              True
# 3                        True                             False
# 4                       False                             False
#
#   Damage to the environment         lon        lat number_of_campers
# 0                     False -122.583146  45.494409               NaN
# 1                     False -122.648198  45.499296               1.0
# 2                      True -122.592590  45.533459               8.0
# 3                     False -122.585585  45.560331               2.0
# 4                     False -122.592797  45.533121               NaN
#
# [5 rows x 23 columns]

# %%
dfs = [df, df2]
# dfc = pd.concat(dfs, ignore_index=True, sort=False)
dfc = pd.concat(dfs, ignore_index=False, sort=False)
# dfc.head(8)
len(dfc['Item ID'])
# Out:
# 54339

# %%
len1 = len(df['Date Created'])
len2 = len(df2['Date Created'])
len3 =len(dfc['Date Created'])

print(len1+len2)
print(len1, len2, len3)

#Looks like they concat'd successfully
dfc.to_csv("test_dfc.csv")
# Out:
# 54339
# 21527 32812 54339

# %%
s = dfc['How many campers would you estimate are there?']
s.head(40)
# Out:
# 0                                     5
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                    15
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                     6
# 10                                  NaN
# 11                             Total 13
# 12                                  NaN
# 13                                  NaN
# 14                               15-Oct
# 15                                    1
# 16                                   15
# 17                                  NaN
# 18                                    1
# 19                                  NaN
# 20                                    1
# 21                                  NaN
# 22                                  NaN
# 23    ? Not sure, looks like 5 at least
# 24                                    1
# 25                                5-Apr
# 26                                  one
# 27                                    3
# 28                                    1
# 29                                  NaN
# 30                                  NaN
# 31                                    3
# 32                                  NaN
# 33                                7-May
# 34                                4-Jan
# 35                                    2
# 36                                  NaN
# 37                                5-Apr
# 38                                  NaN
# 39                                  NaN
# Name: How many campers would you estimate are there?, dtype: object

# %%
#Convert any numbers that are written out into integers
islongint = s.str.match('one', na=False)
islongint
#Locate where the 'one' text is
#s.loc[s.str.match('one') == True]
#islongint.loc[731]

dfc.loc[islongint, 'How many campers would you estimate are there?'] = '1'
dfc.loc[731]
# Out:
#             Date Created Date Received    Item ID Status  Follow-Ups  \
# 731  2018-11-09 09:37:00           NaN  1498723.0   Open         1.0
# 731  2018-03-20 09:56:00           NaN  1361285.0    NaN         NaN
#
#     Where is the campsite/concern located? Please provide an address if possible. If no address is available, please provide a complete description of the site's location.  \
# 731                                                SWC
# 731                   Burnside between 3rd and 4th Ave
#
#     If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (User Specified)  \
# 731                                                NaN
# 731                                       4 nw 3rd Ave
#
#     If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (System Verified)  \
# 731                                                NaN
# 731                              400-499 W BURNSIDE ST
#
#      Address ID Property ID        ...         \
# 731         NaN         NaN        ...
# 731         NaN         NaN        ...
#
#     Public intoxication and/or conspicuous drug use (If it is an emergency, please call 9-1-1.)  \
# 731                                              False
# 731                                               True
#
#     Campsite obstructs public right-of-way Misuse of public spaces  \
# 731                                  False                   False
# 731                                   True                    True
#
#     Structures or tents present Excessive trash and/or biohazards  \
# 731                       False                             False
# 731                        True                              True
#
#     Damage to the environment  \
# 731                     False
# 731                      True
#
#     Is there anything else we should know? When do you see people present?  \
# 731                   Tent, cart, trash on Springwater
# 731                                                NaN
#
#             lon        lat number_of_campers
# 731 -122.557769  45.476033               NaN
# 731 -122.674910  45.523160               NaN
#
# [2 rows x 34 columns]

# %%
islongint = s.str.match('two', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '2'

islongint = s.str.match('three', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '3'

islongint = s.str.match('four', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '4'

islongint = s.str.match('five', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '5'

islongint = s.str.match('six', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '6'

islongint = s.str.match('seven', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '7'

islongint = s.str.match('eight', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '8'

islongint = s.str.match('nine', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '9'

islongint = s.str.match('r"ten\s"', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '10'

islongint = s.str.match('fifteen', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '15'

islongint = s.str.match('twenty', na=False)
dfc.loc[islongint, 'How many campers would you estimate are there?'] = '20'

# %%
s.loc[s.str.match('one') == True]
# Out:
# 26                                                     one
# 896                                                    one
# 2598                                               one man
# 2897                                              one tent
# 3247                                         one maybe two
# 3679                                                   one
# 4128                                                   one
# 4465                                                   one
# 5105     one name is Norman and has huge piles on shopp...
# 5120                               one definitely, maybe 2
# 6556                                            one or two
# 10112                                                  one
# 10327                    one now, but there have been more
# 10461                                                  one
# 10565                                                  one
# 10795                                                  one
# 11553                                                  one
# 11658                                                  one
# 12159       one RV camper vehicle and a van no front plate
# 12873                                         one, now 2-3
# 13853                                      one, maybe two.
# 13858                                      one, maybe two.
# 14561                                                  one
# 15055                                                  one
# 17284                                                  one
# 18485                                                  one
# 18881                                                  one
# 20294                             one recreational vehicle
# 21150                                           one or two
# 21416                                                  one
# Name: How many campers would you estimate are there?, dtype: object

# %%
# Number of rows without any digit in the 'How many campers...' column
s.str.extract(r"(\d+)", expand=False).isnull().sum()
# Out:
# 33245

# %%
#help(s.str.extract)
s.head(20)
#s.loc[17385]
# Out:
# 0            5
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5           15
# 6          NaN
# 7          NaN
# 8          NaN
# 9            6
# 10         NaN
# 11    Total 13
# 12         NaN
# 13         NaN
# 14      15-Oct
# 15           1
# 16          15
# 17         NaN
# 18           1
# 19         NaN
# Name: How many campers would you estimate are there?, dtype: object

# %%
ROW_WITH_MULTIPLE_NUMBERS = 17385
s.loc[ROW_WITH_MULTIPLE_NUMBERS]
# Out:
# 17385      NaN
# 17385    15-20
# Name: How many campers would you estimate are there?, dtype: object

# %%
# First pull out any rows with months in the string, replace with NaN (K)
#(\d+-Apr$)   This will pull out specifically the month of April. 
#(\d{1,2})-([A-Z][a-z]{2}) pulls out all months. 

isbaddate = s.str.match(r"(\d{1,2})-([A-Z][a-z]{2})", na=False)
isbaddate
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14        True
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 32782    False
# 32783    False
# 32784    False
# 32785    False
# 32786    False
# 32787    False
# 32788    False
# 32789    False
# 32790    False
# 32791    False
# 32792    False
# 32793    False
# 32794    False
# 32795    False
# 32796    False
# 32797    False
# 32798    False
# 32799    False
# 32800    False
# 32801    False
# 32802    False
# 32803    False
# 32804    False
# 32805    False
# 32806    False
# 32807    False
# 32808    False
# 32809    False
# 32810    False
# 32811    False
# Name: How many campers would you estimate are there?, Length: 54339, dtype: bool

# %%
#Check out loc, iloc, and ix

# %%
dfc.loc[isbaddate, 'How many campers would you estimate are there?'] = np.nan

# %%
dfc
# Out:
#               Date Created Date Received    Item ID    Status  Follow-Ups  \
# 0      2018-11-19 14:44:00      11/19/18  1503591.0      Open         0.0
# 1      2018-11-19 14:35:00      11/19/18  1503582.0      Open         0.0
# 2      2018-11-19 14:29:00           NaN  1503576.0      Open         0.0
# 3      2018-11-19 14:26:00           NaN  1503571.0      Open         0.0
# 4      2018-11-19 14:24:00           NaN  1503567.0      Open         0.0
# 5      2018-11-19 14:23:00      11/19/18  1503563.0      Open         0.0
# 6      2018-11-19 14:22:00           NaN  1503560.0      Open         0.0
# 7      2018-11-19 14:21:00           NaN  1503556.0      Open         0.0
# 8      2018-11-19 14:19:00           NaN  1503554.0      Open         0.0
# 9      2018-11-19 14:19:00      11/19/18  1503552.0      Open         0.0
# 10     2018-11-19 14:16:00           NaN  1503547.0      Open         0.0
# 11     2018-11-19 14:01:00      11/19/18  1503525.0      Open         0.0
# 12     2018-11-19 13:25:00           NaN  1503483.0      Open         0.0
# 13     2018-11-19 12:46:00           NaN  1503444.0      Open         0.0
# 14     2018-11-19 12:45:00      11/19/18  1503443.0      Open         0.0
# 15     2018-11-19 12:38:00      11/19/18  1503437.0      Open         0.0
# 16     2018-11-19 12:37:00      11/19/18  1503436.0      Open         0.0
# 17     2018-11-19 12:21:00           NaN  1503420.0      Open         0.0
# 18     2018-11-19 12:09:00      11/19/18  1503412.0      Open         0.0
# 19     2018-11-19 12:09:00      11/19/18  1503411.0      Open         0.0
# 20     2018-11-19 12:08:00      11/19/18  1503409.0      Open         0.0
# 21     2018-11-19 12:07:00           NaN  1503408.0      Open         1.0
# 22     2018-11-19 12:03:00      11/19/18  1503403.0  Referred         2.0
# 23     2018-11-19 11:41:00      11/19/18  1503362.0  Referred         2.0
# 24     2018-11-19 11:26:00      11/19/18  1503347.0  Referred         2.0
# 25     2018-11-19 11:23:00      11/19/18  1503343.0  Referred         2.0
# 26     2018-11-19 11:20:00      11/19/18  1503340.0  Referred         2.0
# 27     2018-11-19 11:03:00      11/19/18  1503319.0      Open         0.0
# 28     2018-11-19 10:40:00      11/19/18  1503282.0  Referred         2.0
# 29                     NaT           NaN        NaN       NaN         NaN
# ...                    ...           ...        ...       ...         ...
# 32782  2016-07-05 09:47:00           NaN  1032705.0       NaN         NaN
# 32783  2016-07-04 20:58:00           NaN  1031655.0       NaN         NaN
# 32784  2016-07-04 20:35:00           NaN  1031615.0       NaN         NaN
# 32785  2016-07-04 15:19:00           NaN  1031441.0       NaN         NaN
# 32786  2016-07-04 11:54:00           NaN  1031395.0       NaN         NaN
# 32787  2016-07-03 19:58:00           NaN  1030986.0       NaN         NaN
# 32788  2016-07-03 19:32:00           NaN  1030982.0       NaN         NaN
# 32789  2016-07-03 19:14:00           NaN  1030980.0       NaN         NaN
# 32790  2016-07-03 18:23:00           NaN  1030973.0       NaN         NaN
# 32791  2016-07-03 15:21:00           NaN  1030946.0       NaN         NaN
# 32792  2016-07-03 13:41:00           NaN  1030937.0       NaN         NaN
# 32793  2016-07-03 12:05:00           NaN  1030919.0       NaN         NaN
# 32794  2016-07-03 11:22:00           NaN  1030911.0       NaN         NaN
# 32795  2016-07-03 10:13:00           NaN  1030905.0       NaN         NaN
# 32796  2016-07-03 08:38:00           NaN  1030890.0       NaN         NaN
# 32797  2016-07-02 20:58:00           NaN  1030787.0       NaN         NaN
# 32798  2016-07-02 10:08:00           NaN  1030703.0       NaN         NaN
# 32799  2016-07-02 09:41:00           NaN  1030695.0       NaN         NaN
# 32800  2016-07-01 19:03:00           NaN  1030591.0       NaN         NaN
# 32801  2016-07-01 16:32:00           NaN  1030571.0       NaN         NaN
# 32802  2016-07-01 14:45:00           NaN  1030513.0       NaN         NaN
# 32803  2016-07-01 14:42:00           NaN  1030512.0       NaN         NaN
# 32804  2016-07-01 14:02:00           NaN  1030484.0       NaN         NaN
# 32805  2016-07-01 12:40:00           NaN  1030426.0       NaN         NaN
# 32806  2016-07-01 12:17:00           NaN  1030410.0       NaN         NaN
# 32807  2016-07-01 11:03:00           NaN  1030353.0       NaN         NaN
# 32808  2016-07-01 08:57:00           NaN  1030264.0       NaN         NaN
# 32809  2016-07-01 08:16:00           NaN  1030242.0       NaN         NaN
# 32810  2016-07-01 07:58:00           NaN  1030232.0       NaN         NaN
# 32811  2016-07-01 06:57:00           NaN  1030192.0       NaN         NaN
#
#       Where is the campsite/concern located? Please provide an address if possible. If no address is available, please provide a complete description of the site's location.  \
# 0                                      7519 N Leonard st
# 1                                                   test
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5      I-84 off-ramp at SE 57th, between the ramp and...
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9      SE 83rd Avenue between SE Bush St. and Eastpor...
# 10                                                   NaN
# 11            82nd Halsey off ramp and behind sound wall
# 12                                                   NaN
# 13                                                   NaN
# 14                                NW 17th and NW Raleigh
# 15                                NW Thurman and NW 20th
# 16                                       81st and Halsey
# 17                                                   NaN
# 18                                      1508 NE Schuyler
# 19     East side of Greeley Ave on both sides of Goin...
# 20                                        810 SE Belmont
# 21                                       Stuff n' Things
# 22     I-5 south exit to Rosa Parks Way on west side ...
# 23                  across from 1831 SW 14th Avenue-ODOT
# 24                            4774 SE Milwaukie Ave-ODOT
# 25                            NE 81st and NE Halsey-ODOT
# 26                            NE 68th and NE Halsey-ODOT
# 27                                          2236 SE 10th
# 28              ODOT proerty on ne 69th and ne halsey st
# 29                                                   NaN
# ...                                                  ...
# 32782  On the hillside above Maletis Beverage in Swan...
# 32783       Peter Paulson Apts and 12th Ave Terrace Apts
# 32784                                5625 SE Powell Blvd
# 32785                             2727 NW 29th St. 97210
# 32786                                                NaN
# 32787                                                NaN
# 32788       Peter Paulson Apts and 12th Ave Terrace Apts
# 32789                                                NaN
# 32790                                7200 SE 92nd Avenue
# 32791  Ground dead end road on right side of 2915 SE ...
# 32792                                                NaN
# 32793                                                NaN
# 32794                                                NaN
# 32795                                                NaN
# 32796                                  raymond city park
# 32797                                   Khunamokwst Park
# 32798                                                NaN
# 32799         Across from 1919 SE 84th Ave/Harrison Park
# 32800      To the right (south side) of 206 ne 102nd ave
# 32801   NE 122nd and Glisan - Winco Foods off San Rafael
# 32802  Front of the building in the entry way and the...
# 32803  Beggar's Tick Wildlife Refuge SE 112th and Foster
# 32804  SE Crystal Springs and 82nd - btwn Campbell Fe...
# 32805                                   1500 SW 11th Ave
# 32806                                SE 94th and Lincoln
# 32807                              SE 165th and Division
# 32808  SE Cesar Chavez and 37th on Oak at Laurelhurst...
# 32809   SE Oak Street sidewalk, between SE 13th and 14th
# 32810                                                NaN
# 32811                                                NaN
#
#       If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (User Specified)  \
# 0                          N leonard st and N Chicago st
# 1                                                     to
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                    SE Hoyt and SE 57th
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                         SE 83rd & Bush
# 10                                                   NaN
# 11                                      1606 NE 81st ave
# 12                                                   NaN
# 13                                                   NaN
# 14                                NW 17th and NW Raleigh
# 15                                NW Thurman and NW 20th
# 16                                       81st and Halsey
# 17                                                   NaN
# 18                                      1508 NE Schuyler
# 19                            N Going St and Greeley Ave
# 20                                    SE 8th and Yamhill
# 21                                                   NaN
# 22                      N Montana Ave and Rosa Parks Way
# 23                                   1831 SW 14th Avenue
# 24                                SE Milwakie & Schiller
# 25                                 Ne 81st and NE Halsey
# 26                                 NE 68th and NE Halsey
# 27                                          2236 SE 10th
# 28                                      1433 ne 69th ave
# 29                                                   NaN
# ...                                                  ...
# 32782                                       700 N Cutter
# 32783               1530 SW 13th Ave, Portland, OR 97201
# 32784                         Se 57th and se Powell blvd
# 32785                                 2727 NW 29th 97210
# 32786                                                NaN
# 32787                                                NaN
# 32788               1530 SW 13th Ave, Portland, OR 97201
# 32789                                                NaN
# 32790                                7200 SE 92nd Avenue
# 32791                                  2915 SE 138th Ave
# 32792                                                NaN
# 32793                                                NaN
# 32794                                                NaN
# 32795                                                NaN
# 32796                                      5006 se 115th
# 32797                            52nd Ave and Alberta NE
# 32798                                                NaN
# 32799                                   1919 SE 84th Ave
# 32800                                   206 ne 102nd ave
# 32801                                NE 122nd and Glisan
# 32802                                 1727 NW Hot Street
# 32803                                SE 112th and Foster
# 32804                        SE Crystal Springs and 82nd
# 32805                                   1500 SW 11th Ave
# 32806                                SE 94th and Lincoln
# 32807                              SE 165th and Division
# 32808                            SE Cesar Chavez and Oak
# 32809                                     1300 SE Oak St
# 32810                                                NaN
# 32811                                                NaN
#
#       If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (System Verified)  \
# 0                                     7410 N CHICAGO AVE
# 1                                        1220 SW 5TH AVE
# 2                                                    NaN
# 3                                    700-799 NE BROADWAY
# 4                     0-0 SW MONTGOMERY ST-I405 FWY RAMP
# 5                          0-0 NE I84 FWY-GLISAN ST RAMP
# 6                          0-0 NE I84 FWY-GLISAN ST RAMP
# 7                  8130-8199 NE HALSEY ST-HALSEY ST RAMP
# 8                   16-23 SE MORRISON BRG-WATER AVE RAMP
# 9                                  3800-3899 SE 83RD AVE
# 10                                           0-0 I84 FWY
# 11                                      1707 NE 82ND AVE
# 12                                                   NaN
# 13                            12530-12649 SE POWELL BLVD
# 14                        0-0 NW HWY 30-FREMONT BRG RAMP
# 15                   0-2049 NW THURMAN ST-VAUGHN ST RAMP
# 16                                 1400-1499 NE 81ST AVE
# 17                                  1100-1199 SE PINE ST
# 18                                   1508 NE SCHUYLER ST
# 19                                  2400-2499 N GOING ST
# 20                                     810 SE BELMONT ST
# 21                                 5896-5999 SE 43RD AVE
# 22                               6500-6599 N MONTANA AVE
# 23                                 1800-1849 SW 14TH AVE
# 24                              1500-1599 SE SCHILLER ST
# 25                                 1400-1499 NE 81ST AVE
# 26                                                   NaN
# 27                                       2220 SE 9TH AVE
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 32782                             7000-7049 N CUTTER CIR
# 32783                                   1530 SW 13TH AVE
# 32784                       SE 57TH AVE & SE POWELL BLVD
# 32785                                   2727 NW 29TH AVE
# 32786                                                NaN
# 32787                            5200-5499 NE ALBERTA ST
# 32788                                   1530 SW 13TH AVE
# 32789                                1300-1399 SE OAK ST
# 32790                                   7200 SE 92ND AVE
# 32791                                  2915 SE 138TH AVE
# 32792            2100-2106 SE MARTIN LUTHER KING JR BLVD
# 32793                                                NaN
# 32794                          8800-8999 SE LAFAYETTE ST
# 32795                                800-899 N RUSSET ST
# 32796                                  5006 SE 115TH AVE
# 32797                        NE 52ND AVE & NE ALBERTA ST
# 32798                              8900-8999 NE GOING ST
# 32799                                   1919 SE 84TH AVE
# 32800                                   206 NE 102ND AVE
# 32801                        NE 122ND AVE & NE GLISAN ST
# 32802                               1700-1799 NW HOYT ST
# 32803                         SE 110TH DR & SE 111TH AVE
# 32804              SE 82ND AVE & SE CRYSTAL SPRINGS BLVD
# 32805                                   1500 SW 11TH AVE
# 32806                        SE 94TH AVE & SE LINCOLN ST
# 32807                      SE 165TH AVE & SE DIVISION ST
# 32808                           SE 39TH BLVD & SE OAK ST
# 32809                                     1300 SE OAK ST
# 32810               5600-5649 SE POWELL BLVD FRONTAGE RD
# 32811                                         0-0 I5 FWY
#
#        Address ID Property ID        ...         \
# 0        557114.0         NaN        ...
# 1        646159.0     R246102        ...
# 2             0.0         NaN        ...
# 3             0.0         NaN        ...
# 4             0.0         NaN        ...
# 5             0.0         NaN        ...
# 6             0.0         NaN        ...
# 7             0.0         NaN        ...
# 8             0.0         NaN        ...
# 9             0.0         NaN        ...
# 10            0.0         NaN        ...
# 11       611448.0     R194147        ...
# 12            0.0         NaN        ...
# 13            0.0         NaN        ...
# 14            0.0         NaN        ...
# 15            0.0         NaN        ...
# 16            0.0         NaN        ...
# 17            0.0         NaN        ...
# 18       603368.0     R182431        ...
# 19            0.0         NaN        ...
# 20       646544.0     R233860        ...
# 21            0.0         NaN        ...
# 22            0.0         NaN        ...
# 23            0.0         NaN        ...
# 24            0.0         NaN        ...
# 25            0.0         NaN        ...
# 26            0.0         NaN        ...
# 27       138882.0     R276035        ...
# 28            0.0         NaN        ...
# 29            NaN         NaN        ...
# ...           ...         ...        ...
# 32782         NaN         NaN        ...
# 32783         NaN         NaN        ...
# 32784         NaN         NaN        ...
# 32785         NaN         NaN        ...
# 32786         NaN         NaN        ...
# 32787         NaN         NaN        ...
# 32788         NaN         NaN        ...
# 32789         NaN         NaN        ...
# 32790         NaN         NaN        ...
# 32791         NaN         NaN        ...
# 32792         NaN         NaN        ...
# 32793         NaN         NaN        ...
# 32794         NaN         NaN        ...
# 32795         NaN         NaN        ...
# 32796         NaN         NaN        ...
# 32797         NaN         NaN        ...
# 32798         NaN         NaN        ...
# 32799         NaN         NaN        ...
# 32800         NaN         NaN        ...
# 32801         NaN         NaN        ...
# 32802         NaN         NaN        ...
# 32803         NaN         NaN        ...
# 32804         NaN         NaN        ...
# 32805         NaN         NaN        ...
# 32806         NaN         NaN        ...
# 32807         NaN         NaN        ...
# 32808         NaN         NaN        ...
# 32809         NaN         NaN        ...
# 32810         NaN         NaN        ...
# 32811         NaN         NaN        ...
#
#       Public intoxication and/or conspicuous drug use (If it is an emergency, please call 9-1-1.)  \
# 0                                                   True
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# 5                                                   True
# 6                                                  False
# 7                                                  False
# 8                                                  False
# 9                                                   True
# 10                                                 False
# 11                                                  True
# 12                                                 False
# 13                                                 False
# 14                                                 False
# 15                                                 False
# 16                                                 False
# 17                                                 False
# 18                                                 False
# 19                                                 False
# 20                                                  True
# 21                                                 False
# 22                                                  True
# 23                                                 False
# 24                                                  True
# 25                                                 False
# 26                                                 False
# 27                                                 False
# 28                                                  True
# 29                                                   NaN
# ...                                                  ...
# 32782                                              False
# 32783                                               True
# 32784                                              False
# 32785                                              False
# 32786                                              False
# 32787                                              False
# 32788                                               True
# 32789                                              False
# 32790                                              False
# 32791                                               True
# 32792                                              False
# 32793                                              False
# 32794                                              False
# 32795                                              False
# 32796                                              False
# 32797                                              False
# 32798                                              False
# 32799                                              False
# 32800                                               True
# 32801                                              False
# 32802                                              False
# 32803                                               True
# 32804                                              False
# 32805                                              False
# 32806                                              False
# 32807                                               True
# 32808                                              False
# ...
# 32793                                  False                   False
# 32794                                  False                   False
# 32795                                  False                   False
# 32796                                  False                   False
# 32797                                  False                    True
# 32798                                  False                   False
# 32799                                   True                    True
# 32800                                  False                    True
# 32801                                  False                    True
# 32802                                  False                    True
# 32803                                   True                    True
# 32804                                   True                    True
# 32805                                   True                    True
# 32806                                  False                    True
# 32807                                   True                    True
# 32808                                   True                    True
# 32809                                   True                    True
# 32810                                  False                   False
# 32811                                  False                   False
#
#       Structures or tents present Excessive trash and/or biohazards  \
# 0                            True                              True
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
# 5                            True                              True
# 6                           False                             False
# 7                           False                             False
# 8                           False                             False
# 9                            True                              True
# 10                          False                             False
# 11                           True                              True
# 12                          False                             False
# 13                          False                             False
# 14                           True                              True
# 15                          False                              True
# 16                           True                              True
# 17                          False                             False
# 18                           True                             False
# 19                           True                              True
# 20                           True                              True
# 21                          False                             False
# 22                           True                              True
# 23                           True                              True
# 24                           True                              True
# 25                           True                             False
# 26                           True                             False
# 27                           True                             False
# 28                           True                              True
# 29                            NaN                               NaN
# ...                           ...                               ...
# 32782                        True                                No
# 32783                        True                               Yes
# 32784                        True                               Yes
# 32785                       False                               Yes
# 32786                       False                                No
# 32787                       False                                No
# 32788                        True                               Yes
# 32789                       False                                No
# 32790                       False                               Yes
# 32791                        True                               Yes
# 32792                       False                                No
# 32793                       False                                No
# 32794                       False                                No
# 32795                       False                                No
# 32796                        True                                No
# 32797                       False                               Yes
# 32798                       False                                No
# 32799                        True                                No
# 32800                        True                               Yes
# 32801                       False                                No
# 32802                        True                               Yes
# 32803                        True                               Yes
# 32804                       False                                No
# 32805                       False                                No
# 32806                       False                                No
# 32807                        True                               Yes
# 32808                        True                               Yes
# 32809                        True                               Yes
# 32810                       False                                No
# 32811                       False                                No
#
#       Damage to the environment  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# 5                          True
# 6                         False
# 7                         False
# 8                         False
# 9                          True
# 10                        False
# 11                        False
# 12                        False
# 13                        False
# 14                         True
# 15                         True
# 16                         True
# 17                        False
# 18                         True
# 19                        False
# 20                         True
# 21                        False
# 22                        False
# 23                        False
# 24                        False
# 25                         True
# 26                        False
# 27                        False
# 28                         True
# 29                          NaN
# ...                         ...
# 32782                       Yes
# 32783                       Yes
# 32784                       Yes
# 32785                       Yes
# 32786                        No
# 32787                        No
# 32788                       Yes
# 32789                        No
# 32790                       Yes
# 32791                        No
# 32792                        No
# 32793                        No
# 32794                        No
# 32795                        No
# 32796                        No
# 32797                        No
# 32798                        No
# 32799                        No
# 32800                       Yes
# 32801                        No
# 32802                       Yes
# 32803                       Yes
# 32804                        No
# 32805                        No
# 32806                        No
# 32807                        No
# 32808                        No
# 32809                        No
# 32810                        No
# 32811                        No
#
#       Is there anything else we should know? When do you see people present?  \
# 0      Campers are using public space and the racquet...
# 1                                                    NaN
# 2      Large and growing camp along soundwall on east...
# 3      Camp on or next to sidewalk on Broadway at NE ...
# 4      Camps and remains of camps in median on west s...
# 5      Constantly walking back and forth across the f...
# 6      Tent city in median at 58th aveneue exit from ...
# 7      Camp under Halsey overpass on west side of NE ...
# 8      Massive tent city has formed under overpass. F...
# 9                                                    NaN
# 10     Camps in or straddling ROW on north side of Ea...
# 11     Too much drug activities at night.Campers keep...
# 12                                                   NaN
# 13     2 campsites here. One has been there for month...
# 14     This camp has continued to build over the last...
# 15     Believe this camp is occupied by a single woma...
# 16                                                   NaN
# 17     report #5, same group, same crap. Now we have ...
# 18                                                   NaN
# 19     Campers have been in street creating traffic h...
# 20                                                   NaN
# 21     There is a camp that pops up nightly at Woodst...
# 22     Campers stole property from caller and vandali...
# 23     My tenant attorney Rebecca Cambreleng asked me...
# 24     4774 SE Milwaukie Ave, near 4774 SE Milwaukie ...
# 25     Tents reappeared within three days of it being...
# 26     Tents cleared out four days ago. Constant prob...
# 27                                                   NaN
# 28     Thank you for having this campsite cleaned up ...
# 29                                                   NaN
# ...                                                  ...
# 32782                                                NaN
# 32783                                                NaN
# 32784                                                NaN
# 32785                                                NaN
# 32786                                                NaN
# 32787                                                NaN
# 32788                                                NaN
# 32789                                                NaN
# 32790                                                NaN
# 32791                                                NaN
# 32792                                                NaN
# 32793                                                NaN
# 32794                                                NaN
# 32795                                                NaN
# 32796                                                NaN
# 32797                                                NaN
# 32798                                                NaN
# 32799                                                NaN
# 32800                                                NaN
# 32801                                                NaN
# 32802                                                NaN
# 32803                                                NaN
# 32804                                                NaN
# 32805                                                NaN
# 32806                                                NaN
# 32807                                                NaN
# 32808                                                NaN
# 32809                                                NaN
# 32810                                                NaN
# 32811                                                NaN
#
#               lon        lat number_of_campers
# 0     -122.755294  45.591748               NaN
# 1     -122.679057  45.514999               NaN
# 2     -122.565987  45.556555               NaN
# 3     -122.658411  45.534961               NaN
# 4     -122.689916  45.512986               NaN
# 5     -122.604919  45.527436               NaN
# 6     -122.604756  45.527441               NaN
# 7     -122.579237  45.534465               NaN
# 8     -122.666672  45.516523               NaN
# 9     -122.577859  45.494520               NaN
# 10    -122.579629  45.533431               NaN
# 11    -122.579323  45.534868               NaN
# 12    -122.689068  45.512828               NaN
# 13    -122.533425  45.497127               NaN
# 14    -122.688213  45.534602               NaN
# 15    -122.694021  45.536459               NaN
# 16    -122.580042  45.533576               NaN
# 17    -122.653899  45.520691               NaN
# 18    -122.650168  45.535599               NaN
# 19    -122.691787  45.556072               NaN
# 20    -122.657396  45.516146               NaN
# 21    -122.618666  45.479659               NaN
# 22    -122.679719  45.570262               NaN
# 23    -122.690200  45.513399               NaN
# 24    -122.650081  45.487449               NaN
# 25    -122.580109  45.533598               NaN
# 26    -122.592704  45.533462               NaN
# 27    -122.655955  45.507008               NaN
# 28    -122.592792  45.533428               NaN
# 29            NaN        NaN               NaN
# ...           ...        ...               ...
# 32782 -122.709953  45.573255               NaN
# 32783 -122.687903  45.514931               NaN
# 32784 -122.604074  45.497467               2.0
# 32785 -122.711742  45.541973               2.0
# 32786 -122.590396  45.512828               NaN
# 32787 -122.608470  45.559143               NaN
# 32788 -122.687903  45.514931               NaN
# 32789 -122.652326  45.520036               NaN
# 32790 -122.567574  45.470492               NaN
# 32791 -122.521801  45.501122               1.0
# 32792 -122.660973  45.507527               NaN
# 32793 -122.549628  45.478131               NaN
# 32794 -122.570691  45.496450               NaN
# 32795 -122.674958  45.577961               NaN
# 32796 -122.543456  45.486192               1.0
# 32797 -122.609568  45.559127               2.0
# 32798 -122.570343  45.556541               NaN
# 32799 -122.577314  45.508812               NaN
# 32800 -122.557911  45.524077               NaN
# 32801 -122.537749  45.526293               5.0
# 32802 -122.688720  45.527241               2.0
# 32803 -122.549379  45.476045              30.0
# 32804 -122.579044  45.465096               0.0
# 32805 -122.685819  45.514623               2.0
# 32806 -122.566404  45.507931               3.0
# 32807 -122.493678  45.504578               6.0
# 32808 -122.623040  45.520285               7.0
# 32809 -122.652203  45.519832               3.0
# 32810 -122.604487  45.497193               NaN
# 32811 -122.665302  45.528663               NaN
#
# [54339 rows x 34 columns]

# %%
# Pull out any numbers in that string
temp = s.str.extractall(r"(?P<Numbers>\d+)")
temp
# Out:
#             Numbers
#       match
# 0     0           5
# 5     0          15
# 9     0           6
# 11    0          13
# 14    0          15
# 15    0           1
# 16    0          15
# 18    0           1
# 20    0           1
# 23    0           5
# 24    0           1
# 25    0           5
# 27    0           3
# 28    0           1
# 31    0           3
# 33    0           7
# 34    0           4
# 35    0           2
# 37    0           5
# 40    0           3
# 43    0           5
# 44    0           4
# 46    0           5
# 52    0           4
# 53    0           4
# 57    0           1
# 58    0           3
# 60    0          10
# 61    0           5
# 63    0           3
# ...             ...
# 32739 0           7
# 32740 0          30
# 32741 0           5
#       1          10
# 32743 0          10
# 32744 0          10
# 32745 0         200
# 32747 0           6
# 32752 0           3
# 32753 0           2
# 32764 0          10
# 32767 0           6
# 32768 0           1
# 32772 0           3
# 32776 0           6
# 32777 0          20
# 32784 0           2
# 32785 0           2
# 32791 0           1
# 32796 0           1
# 32797 0           2
# 32801 0           5
# 32802 0           2
# 32803 0          30
# 32804 0           0
# 32805 0           2
# 32806 0           3
# 32807 0           6
# 32808 0           7
# 32809 0           3
#
# [23394 rows x 1 columns]

# %%
temp2 = temp.Numbers.astype(float)

#temp2.loc[25].mean()
#THIS is correct.

# %%
temp2.index.names = ['record','match']
temp2.index.names

temp3 = temp2.groupby(level=['record']).mean()
temp3
# Out:
# record
# 0          5.0
# 1          1.0
# 2          8.0
# 3          2.0
# 5         15.0
# 9          6.0
# 10         4.0
# 11         8.5
# 14        15.0
# 15         1.0
# 16         8.0
# 17         4.5
# 18         1.0
# 20         1.0
# 21         2.0
# 23         5.0
# 24         1.0
# 25         5.0
# 27         3.0
# 28         1.0
# 29        10.0
# 31         3.0
# 33         7.0
# 34         3.0
# 35         2.0
# 37         3.5
# 38        10.0
# 40         3.0
# 41         3.0
# 43         5.0
#          ...
# 32736      8.0
# 32739      7.0
# 32740     30.0
# 32741      7.5
# 32743     10.0
# 32744     10.0
# 32745    200.0
# 32747      6.0
# 32752      3.0
# 32753      2.0
# 32764     10.0
# 32767      6.0
# 32768      1.0
# 32772      3.0
# 32776      6.0
# 32777     20.0
# 32784      2.0
# 32785      2.0
# 32791      1.0
# 32796      1.0
# 32797      2.0
# 32801      5.0
# 32802      2.0
# 32803     30.0
# 32804      0.0
# 32805      2.0
# 32806      3.0
# 32807      6.0
# 32808      7.0
# 32809      3.0
# Name: Numbers, Length: 17496, dtype: float64

# %%
dfc2 = dfc.assign(number_of_campers=temp3)

# %%
dfc2.columns[7]
# Out:
# 'If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (System Verified)'

# %%
# dfc3 = dfc2.dropna(subset=['lon','lat', dfc2.columns[5], dfc2.columns[6], dfc2.columns[7]])
#NOTE: This is too strong; find the subset that is all 5 together (AND logic), not all 5 (OR logic)
#NOTE: Did not end up subsetting; will do this in the R notebook.
                           
# len(dfc3['number_of_campers'])
len(dfc2['number_of_campers'])
# Out:
# 54339

# %%
# dfc2.to_csv('../data/onepointcontactreports/campsite_reports_processed_cols_nums.csv')
dfc2.to_csv('../data/onepointcontactreports/campsite_reports_processed_cols_nums_02.csv')

# %%
#np.mean(a, axis=0) 
#something like this will take the mean of each row for the indices and return a single-column df (or) array.
#from there, I can append the column to the dataframe. 
#from, I can filter out rows that have NaN either for the # of campers or for hte lat/long to get the final dataset.

# %%
#temp2 = temp.Numbers.astype(float)

#temp2.loc[27].mean()
#THIS is correct.

# %%
#result = cleanse_data(df)

# %%
#result
# Out:
#              Date Created    Item ID  \
# 0     2017-03-31 21:26:00  1166167.0
# 1     2017-03-31 21:13:00  1166163.0
# 2     2017-03-31 21:12:00  1166162.0
# 3     2017-03-31 20:42:00  1166158.0
# 4     2017-03-31 20:40:00  1166157.0
# 5     2017-03-31 20:37:00  1166156.0
# 6     2017-03-31 20:34:00  1166154.0
# 7     2017-03-31 20:16:00  1166152.0
# 8     2017-03-31 19:41:00  1166149.0
# 9     2017-03-31 19:06:00  1166142.0
# 10    2017-03-31 18:44:00  1166137.0
# 11    2017-03-31 18:40:00  1166134.0
# 12    2017-03-31 17:36:00  1166117.0
# 13    2017-03-31 17:21:00  1166112.0
# 14    2017-03-31 17:14:00  1166110.0
# 15    2017-03-31 17:11:00  1166107.0
# 16    2017-03-31 16:59:00  1166097.0
# 17                    NaT        NaN
# 18    2017-03-31 16:47:00  1166091.0
# 19    2017-03-31 16:42:00  1166090.0
# 20    2017-03-31 16:28:00  1166082.0
# 21    2017-03-31 15:29:00  1166059.0
# 22    2017-03-31 14:45:00  1166025.0
# 23    2017-03-31 14:29:00  1166017.0
# 24    2017-03-31 14:02:00  1165993.0
# 25    2017-03-31 13:31:00  1165931.0
# 26    2017-03-31 13:29:00  1165928.0
# 27    2017-03-31 13:28:00  1165921.0
# 28    2017-03-31 13:27:00  1165919.0
# 29    2017-03-31 13:26:00  1165917.0
# ...                   ...        ...
# 17368 2016-07-02 05:03:00  1030667.0
# 17369 2016-07-01 19:03:00  1030591.0
# 17370 2016-07-01 16:59:00  1030576.0
# 17371 2016-07-01 16:32:00  1030571.0
# 17372 2016-07-01 16:00:00  1030557.0
# 17373 2016-07-01 14:45:00  1030513.0
# 17374 2016-07-01 14:42:00  1030512.0
# 17375 2016-07-01 14:13:00  1030492.0
# 17376 2016-07-01 14:02:00  1030484.0
# 17377 2016-07-01 13:01:00  1030438.0
# 17378 2016-07-01 12:54:00  1030432.0
# 17379 2016-07-01 12:42:00  1030429.0
# 17380 2016-07-01 12:41:00  1030428.0
# 17381                 NaT        NaN
# 17382                 NaT        NaN
# 17383 2016-07-01 12:40:00  1030426.0
# 17384 2016-07-01 12:17:00  1030410.0
# 17385 2016-07-01 11:30:00  1030377.0
# 17386 2016-07-01 11:03:00  1030353.0
# 17387 2016-07-01 10:54:00  1030347.0
# 17388 2016-07-01 10:25:00  1030327.0
# 17389 2016-07-01 10:23:00  1030325.0
# 17390 2016-07-01 08:57:00  1030264.0
# 17391 2016-07-01 08:18:00  1030244.0
# 17392                 NaT        NaN
# 17393                 NaT        NaN
# 17394 2016-07-01 08:16:00  1030242.0
# 17395 2016-07-01 07:58:00  1030232.0
# 17396 2016-07-01 07:47:00  1030221.0
# 17397 2016-07-01 06:57:00  1030192.0
#
#       Where is the campsite/concern located? Please provide an address if possible. If no address is available, please provide a complete description of the site's location.  \
# 0       along MUP North of SE Flavel and East of 92ndAve
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8              Between NE 66th and 67th on NE Sacramento
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12       Page St. between Vancouver Ave and Williams Ave
# 13           SW Grover Street Tunnel (under Naito Pkway)
# 14                                                   NaN
# 15                                                   NaN
# 16     west side of SW 11th Avenue between Jefferson ...
# 17                                                   NaN
# 18                         NE Clackamas St and 103rd Ave
# 19            NE 37th and Sandy Blvd south side of Sandy
# 20                                    East Holladay Park
# 21           SE 79th between Powell Blvd and Franklin St
# 22                                      6605 SE 60th Ave
# 23                                      NE Davis and 7th
# 24                          NE 49th Ave. at NE Mason St.
# 25     Springwater Trail between SE 92nd & I205 overpass
# 26                            92nd and Flavel; NE Corner
# 27                                SW 11th Ave & Columbia
# 28     11310 SE Market St - on 113th and Market behin...
# 29     SW 18th Ave & SW Mill ST Terrace along walking...
# ...                                                  ...
# 17368                                   6518 SE 83rd Ave
# 17369      To the right (south side) of 206 ne 102nd ave
# 17370  south side of Powell Blvd where SE 90th Pl is ...
# 17371   NE 122nd and Glisan - Winco Foods off San Rafael
# 17372                           SE 57 and Powell - 97206
# 17373  Front of the building in the entry way and the...
# 17374  Beggar's Tick Wildlife Refuge SE 112th and Foster
# 17375                   NE San Rafael NE 122nd and 124th
# 17376  SE Crystal Springs and 82nd - btwn Campbell Fe...
# 17377                              14100 SE Holgate Blvd
# 17378                                      937 NW Glisan
# 17379                  SE 72nd between Harold and Insley
# 17380                                  SE 12th and Alder
# 17381                                                NaN
# 17382                                                NaN
# 17383                                   1500 SW 11th Ave
# 17384                                SE 94th and Lincoln
# 17385                 The corner of NE 7th & NE Flanders
# 17386                              SE 165th and Division
# 17387                 SE Clinton between 121st and 122nd
# 17388               17197 se alder street portland 97233
# 17389  parking lot next to empty lot at 7th and Flanders
# 17390  SE Cesar Chavez and 37th on Oak at Laurelhurst...
# 17391                            SE 92nd Avenue & Flavel
# 17392                                                NaN
# 17393                                                NaN
# 17394   SE Oak Street sidewalk, between SE 13th and 14th
# 17395                                                NaN
# 17396  Walking from convention center down to waterfr...
# 17397                                                NaN
#
#       If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (User Specified)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                           2615 NE 58th
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                         118 n Page st
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                NE 37th and Sandy Blvd
# 20                                                   NaN
# 21                                                   NaN
# 22                                      6605 SE 60th Ave
# 23                                        160 6th Ave NE
# 24                                                   NaN
# 25                                           SE 92nd Ave
# 26                                       92nd and Flavel
# 27                                  SW 11th and Columbia
# 28                                       11310 SE Market
# 29                      SW 18th Ave & SW Mill ST Terrace
# ...                                                  ...
# 17368                                   6518 SE 83rd Ave
# 17369                                   206 ne 102nd ave
# 17370                                                NaN
# 17371                                NE 122nd and Glisan
# 17372                                                NaN
# 17373                                 1727 NW Hot Street
# 17374                                SE 112th and Foster
# 17375                                                NaN
# 17376                        SE Crystal Springs and 82nd
# 17377                              14100 SE Holgate Blvd
# 17378                                                NaN
# 17379                                                NaN
# 17380                                    707 SE 12th Ave
# 17381                                                NaN
# 17382                                                NaN
# 17383                                   1500 SW 11th Ave
# 17384                                SE 94th and Lincoln
# 17385                                                NaN
# 17386                              SE 165th and Division
# 17387                                                NaN
# 17388               17197 se alder street portland 97233
# 17389                             7th and Flanders 97232
# 17390                            SE Cesar Chavez and Oak
# 17391                                                NaN
# 17392                                                NaN
# 17393                                                NaN
# 17394                                     1300 SE Oak St
# 17395                                                NaN
# 17396                                         Waterfront
# 17397                                                NaN
#
#       If having difficulty with the map, please type in the nearest address or intersection (for example, SW Market and SW 14th) and scroll to pinpoint the location. (System Verified)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                 9690-9699 SE FLAVEL ST
# 3                               12500-12899 NE SHAVER ST
# 4                               12500-12899 NE SHAVER ST
# 5                               12500-12899 NE SHAVER ST
# 6                               12500-12899 NE SHAVER ST
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                            8780-8799 NE VANCOUVER WAY
# 11                 7400-7499 N COLUMBIA BLVD FRONTAGE RD
# 12                                       0-199 N PAGE ST
# 13                                                   NaN
# 14                          1900-1919 SW MILL STREET TER
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                            NE 37TH AVE & NE HALSEY ST
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 17368                                                NaN
# 17369                                   206 NE 102ND AVE
# 17370                                                NaN
# 17371                        NE 122ND AVE & NE GLISAN ST
# 17372                                                NaN
# 17373                               1700-1799 NW HOYT ST
# 17374                         SE 110TH DR & SE 111TH AVE
# 17375                                                NaN
# 17376              SE 82ND AVE & SE CRYSTAL SPRINGS BLVD
# 17377                                                NaN
# 17378                                                NaN
# 17379                                                NaN
# 17380                                                NaN
# 17381                                                NaN
# 17382                                                NaN
# 17383                                   1500 SW 11TH AVE
# 17384                        SE 94TH AVE & SE LINCOLN ST
# 17385                                                NaN
# 17386                      SE 165TH AVE & SE DIVISION ST
# 17387                                                NaN
# 17388                                                NaN
# 17389                                                NaN
# 17390                           SE 39TH BLVD & SE OAK ST
# 17391                                                NaN
# 17392                                                NaN
# 17393                                                NaN
# 17394                                     1300 SE OAK ST
# 17395               5600-5649 SE POWELL BLVD FRONTAGE RD
# 17396                                                NaN
# 17397                                         0-0 I5 FWY
#
#                  X           Y  Address ID Property ID        State ID  \
# 0            0.000       0.000         NaN         NaN             NaN
# 1      7671608.498  663720.642         NaN         NaN             NaN
# 2      7672165.664  663601.344         NaN         NaN             NaN
# 3      7681419.287  693844.334         NaN         NaN             NaN
# 4      7681264.838  693826.702         NaN         NaN             NaN
# 5      7681237.336  693823.383         NaN         NaN             NaN
# 6      7681516.553  693829.850         NaN         NaN             NaN
# 7      7652801.131  674934.195         NaN         NaN             NaN
# 8            0.000       0.000         NaN         NaN             NaN
# 9      7672043.826  671335.119         NaN         NaN             NaN
# 10     7647994.686  707539.097         NaN         NaN             NaN
# 11     7629256.655  712022.316         NaN         NaN             NaN
# 12     7646864.146  690223.306         NaN         NaN             NaN
# 13           0.000       0.000         NaN         NaN             NaN
# 14     7639443.830  681595.167         NaN         NaN             NaN
# 15     7683480.156  671427.462         NaN         NaN             NaN
# 16           0.000       0.000         NaN         NaN             NaN
# 17             NaN         NaN         NaN         NaN             NaN
# 18           0.000       0.000         NaN         NaN             NaN
# 19     7657658.205  687956.076         NaN         NaN             NaN
# 20           0.000       0.000         NaN         NaN             NaN
# 21           0.000       0.000         NaN         NaN             NaN
# 22           0.000       0.000         NaN         NaN             NaN
# 23           0.000       0.000         NaN         NaN             NaN
# 24           0.000       0.000         NaN         NaN             NaN
# 25           0.000       0.000         NaN         NaN             NaN
# 26           0.000       0.000         NaN         NaN             NaN
# 27           0.000       0.000         NaN         NaN             NaN
# 28           0.000       0.000         NaN         NaN             NaN
# 29           0.000       0.000         NaN         NaN             NaN
# ...            ...         ...         ...         ...             ...
# 17368        0.000       0.000         NaN         NaN             NaN
# 17369  7674729.140  683882.506    637265.0     R319881   1N2E34CB 9400
# 17370        0.000       0.000         NaN         NaN             NaN
# 17371  7679915.357  684559.188         NaN         NaN             NaN
# 17372        0.000       0.000         NaN         NaN             NaN
# 17373  7641246.664  685916.742         NaN         NaN             NaN
# 17374  7676471.062  666319.948         NaN         NaN             NaN
# 17375        0.000       0.000         NaN         NaN             NaN
# 17376  7668761.321  662523.360         NaN         NaN             NaN
# 17377        0.000       0.000         NaN         NaN             NaN
# 17378        0.000       0.000         NaN         NaN             NaN
# 17379        0.000       0.000         NaN         NaN             NaN
# 17380        0.000       0.000         NaN         NaN             NaN
# 17381          NaN         NaN         NaN         NaN             NaN
# 17382          NaN         NaN         NaN         NaN             NaN
# 17383  7641865.418  681297.471   1061033.0         NaN  1S1E04AD 60057
# 17384  7672402.746  678053.016         NaN         NaN             NaN
# 17385        0.000       0.000         NaN         NaN             NaN
# 17386  7691011.175  676362.328         NaN         NaN             NaN
# 17387        0.000       0.000         NaN         NaN             NaN
# 17388        0.000       0.000         NaN         NaN             NaN
# 17389        0.000       0.000         NaN         NaN             NaN
# 17390  7658006.318  682932.181         NaN         NaN             NaN
# 17391        0.000       0.000         NaN         NaN             NaN
# 17392          NaN         NaN         NaN         NaN             NaN
# 17393          NaN         NaN         NaN         NaN             NaN
# 17394  7650529.925  682964.745    159221.0         NaN  1N1E35CD 10500
# 17395  7662540.810  674391.096         NaN         NaN             NaN
# 17396        0.000       0.000         NaN         NaN             NaN
# 17397  7647259.922  686273.162         NaN         NaN             NaN
#
#           ...             What was the make and model of the vehicle?  \
# 0         ...                                                     NaN
# 1         ...                                                     NaN
# 2         ...                                                     NaN
# 3         ...                                                     NaN
# 4         ...                                                     NaN
# 5         ...                                                     NaN
# 6         ...                                                     NaN
# 7         ...                                                     NaN
# 8         ...                                                      OR
# 9         ...                                                     NaN
# 10        ...                                                     NaN
# 11        ...                                                     NaN
# 12        ...                                                     NaN
# 13        ...                                                     NaN
# 14        ...                                                     NaN
# 15        ...                                                     NaN
# 16        ...                                                     NaN
# 17        ...                                                     NaN
# 18        ...                                                     NaN
# 19        ...                                                     NaN
# 20        ...                                                     NaN
# 21        ...                                                     NaN
# 22        ...                                                      Or
# 23        ...                                                  Oregon
# 24        ...       One long camper trailer, two maroon pickups, a...
# 25        ...                                                     NaN
# 26        ...                                                     NaN
# 27        ...                                                      OR
# 28        ...                                     SUV and 15' trailer
# 29        ...                                                     NaN
# ...       ...                                                     ...
# 17368     ...                                                     NaN
# 17369     ...                                                     NaN
# 17370     ...                                                     NaN
# 17371     ...                                                     NaN
# 17372     ...                                                     NaN
# 17373     ...                                                     NaN
# 17374     ...                                                     NaN
# 17375     ...                                                     NaN
# 17376     ...                                                     NaN
# 17377     ...                                                     NaN
# 17378     ...                                                     NaN
# 17379     ...                                                     NaN
# 17380     ...                                                     NaN
# 17381     ...                                                     NaN
# 17382     ...                                                     NaN
# 17383     ...                                                     NaN
# 17384     ...                                                     NaN
# 17385     ...                                                     NaN
# 17386     ...                                                     NaN
# 17387     ...                                                     NaN
# 17388     ...                                                     NaN
# 17389     ...                                                     NaN
# 17390     ...                                                     NaN
# 17391     ...                                                     NaN
# 17392     ...                                                     NaN
# 17393     ...                                                     NaN
# 17394     ...                                                     NaN
# 17395     ...                                                     NaN
# 17396     ...                                                     NaN
# 17397     ...                                                     NaN
#
#                 What is the license plate, if available?  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                  lic # r677979 oregon plate (trailer)
# 29                                                   NaN
# ...                                                  ...
# 17368                                                NaN
# 17369                                                NaN
# 17370                                                NaN
# 17371            Several RVs and a Truck pulling trailer
# 17372                                                NaN
# 17373                                                NaN
# ...
# 21                                                 False
# 22                                                 False
# 23                                                 False
# 24                                                 False
# 25                                                 False
# 26                                                 False
# 27                                                 False
# 28                                                  True
# 29                                                  True
# ...                                                  ...
# 17368                                              False
# 17369                                               True
# 17370                                              False
# 17371                                              False
# 17372                                               True
# 17373                                              False
# 17374                                               True
# 17375                                              False
# 17376                                              False
# 17377                                              False
# 17378                                              False
# 17379                                              False
# 17380                                               True
# 17381                                                NaN
# 17382                                                NaN
# 17383                                              False
# 17384                                              False
# 17385                                               True
# 17386                                               True
# 17387                                               True
# 17388                                               True
# 17389                                              False
# 17390                                              False
# 17391                                              False
# 17392                                                NaN
# 17393                                                NaN
# 17394                                              False
# 17395                                              False
# 17396                                              False
# 17397                                              False
#
#       Campsite obstructs public right-of-way Misuse of public spaces  \
# 0                                       True                    True
# 1                                      False                   False
# 2                                      False                   False
# 3                                      False                   False
# 4                                      False                   False
# 5                                      False                   False
# 6                                      False                   False
# 7                                      False                   False
# 8                                      False                    True
# 9                                      False                   False
# 10                                     False                   False
# 11                                     False                   False
# 12                                      True                   False
# 13                                      True                    True
# 14                                     False                   False
# 15                                     False                   False
# 16                                      True                   False
# 17                                       NaN                     NaN
# 18                                      True                    True
# 19                                      True                    True
# 20                                     False                    True
# 21                                      True                    True
# 22                                      True                    True
# 23                                      True                    True
# 24                                     False                   False
# 25                                     False                    True
# 26                                      True                    True
# 27                                      True                   False
# 28                                     False                   False
# 29                                      True                    True
# ...                                      ...                     ...
# 17368                                  False                    True
# 17369                                  False                    True
# 17370                                  False                   False
# 17371                                  False                    True
# 17372                                  False                    True
# 17373                                  False                    True
# 17374                                   True                    True
# 17375                                   True                   False
# 17376                                   True                    True
# 17377                                   True                    True
# 17378                                  False                   False
# 17379                                  False                    True
# 17380                                   True                    True
# 17381                                    NaN                     NaN
# 17382                                    NaN                     NaN
# 17383                                   True                    True
# 17384                                  False                    True
# 17385                                   True                    True
# 17386                                   True                    True
# 17387                                   True                    True
# 17388                                   True                    True
# 17389                                  False                    True
# 17390                                   True                    True
# 17391                                  False                    True
# 17392                                    NaN                     NaN
# 17393                                    NaN                     NaN
# 17394                                   True                    True
# 17395                                  False                   False
# 17396                                   True                    True
# 17397                                  False                   False
#
#       Structures or tents present Excessive trash and/or biohazards  \
# 0                            True                               Yes
# 1                           False                                No
# 2                           False                                No
# 3                           False                                No
# 4                           False                                No
# 5                           False                                No
# 6                           False                                No
# 7                           False                                No
# 8                            True                                No
# 9                           False                                No
# 10                          False                                No
# 11                          False                                No
# 12                           True                                No
# 13                           True                               Yes
# 14                          False                                No
# 15                          False                                No
# 16                           True                               Yes
# 17                            NaN                               NaN
# 18                          False                               Yes
# 19                           True                               Yes
# 20                           True                               Yes
# 21                          False                               Yes
# 22                           True                               Yes
# 23                           True                               Yes
# 24                           True                                No
# 25                           True                                No
# 26                           True                               Yes
# 27                          False                                No
# 28                          False                                No
# 29                           True                               Yes
# ...                           ...                               ...
# 17368                       False                                No
# 17369                        True                               Yes
# 17370                        True                               Yes
# 17371                       False                                No
# 17372                        True                               Yes
# 17373                        True                               Yes
# 17374                        True                               Yes
# 17375                        True                               Yes
# 17376                       False                                No
# 17377                       False                               Yes
# 17378                        True                               Yes
# 17379                       False                                No
# 17380                        True                               Yes
# 17381                         NaN                               NaN
# 17382                         NaN                               NaN
# 17383                       False                                No
# 17384                       False                                No
# 17385                        True                               Yes
# 17386                        True                               Yes
# 17387                        True                                No
# 17388                        True                               Yes
# 17389                        True                               Yes
# 17390                        True                               Yes
# 17391                        True                               Yes
# 17392                         NaN                               NaN
# 17393                         NaN                               NaN
# 17394                        True                               Yes
# 17395                       False                                No
# 17396                        True                               Yes
# 17397                       False                                No
#
#        Damage to the environment  num_campers
# 0                            Yes            5
# 1                             No          NaN
# 2                             No          NaN
# 3                             No          NaN
# 4                             No          NaN
# 5                             No          NaN
# 6                             No          NaN
# 7                             No          NaN
# 8                            Yes          NaN
# 9                             No          NaN
# 10                            No          NaN
# 11                            No          NaN
# 12                            No            1
# 13                            No          NaN
# 14                            No          NaN
# 15                            No          NaN
# 16                            No            8
# 17                           NaN          NaN
# 18                            No           12
# 19                           Yes            3
# 20                            No          NaN
# 21                            No            6
# 22                           Yes           10
# 23                           Yes          NaN
# 24                            No            1
# 25                           Yes            5
# 26                           Yes            5
# 27                            No            1
# 28                            No            2
# 29                           Yes            2
# ...                          ...          ...
# 17368                         No            2
# 17369                        Yes            6
# 17370                         No           10
# 17371                         No            5
# 17372                        Yes            4
# 17373                        Yes            2
# 17374                        Yes           30
# 17375                         No           12
# 17376                         No            0
# 17377                         No            0
# 17378                         No            1
# 17379                         No          NaN
# 17380                        Yes           10
# 17381                        NaN          NaN
# 17382                        NaN          NaN
# 17383                         No            2
# 17384                         No            3
# 17385                        Yes           30
# 17386                         No            6
# 17387                         No            6
# 17388                        Yes            6
# 17389                         No            2
# 17390                         No            7
# 17391                        Yes          NaN
# 17392                        NaN          NaN
# 17393                        NaN          NaN
# 17394                         No          NaN
# 17395                         No          NaN
# 17396                        Yes           25
# 17397                         No          NaN
#
# [17398 rows x 39 columns]
